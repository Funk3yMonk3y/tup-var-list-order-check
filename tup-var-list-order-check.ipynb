# %%
t = (0, True, 'string')
#Creates Tuple
x = t[0]
#Tuple 1st entry
l = [t[1],t[2]]
#Creates list with 2nd and 3d
print(t)
print(x)
print(l)
l.append(x)
#adds var to List
print(l)
l.reverse()
#reverse order
print(l)
l[1], l[2] = l[2], l[1]
print(t)
print(l)
l1 = l[0]
for el in l: print(el)
for a in t: print(t)
            
if (el == a):print('Die Reihenfolge der Elemente ist gleich!')
if (el != a):print('Die Reihenfolge der Elemente ist nicht gleich')
#checks if tuple is sorted like the list
